# %% [markdown]
# # Exercise: Prediction accuracy
# In the previous exercise, you created the dataset required to predict who among the infected needs to be given a hospital bed immediately. The aim of this exercise is to use that train and test data to train a simple kNN model.
#
#
# ### Instructions:
# - Import necessary libraries
# - Read the file `covid_train.csv` as a pandas dataframe and take a quick look at it
# - Read the file `covid_test.csv` as a pandas dataframe and take a quick look at it
# - With `Urgency` as the response, get the predictor and response variables for both the train and test dataset
# - Initialize and fit your kNN classification model on the train data
# - Predict on the test data and compute the accuracy

# %% [markdown]
# Hints:
# pd.read_csv(filename)
#  Returns a pandas dataframe containing the data and labels from the file data
#
#
# df.head()
# Returns the first 5 rows of the dataframe with the column names
#
#
# KNeighborsClassifier(n_neighbors=k_value)
# Classification-based on k-nearest neighbors.
#
#
# model.fit( )
# Fit the k-nearest neighbors regressor from the training dataset
#
#
# model.predict( )
# Predict the target for the provided data
#
#
# accuracy_score()
# Compute the accuracy classification score

# %%
# Import necessary libraries

# Your code here
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
# Read the datafile "covid_train.csv"
df_train = pd.read_csv("covid_train.csv")

# Take a quick look at the dataframe
df_train.head()
# Out:
#    age  sex  cough  fever  chills  sore_throat  headache  fatigue  Urgency
# 0   30    1      0      0       0            0         0        0        0
# 1   47    1      0      0       0            0         0        0        0
# 2   49    1      0      0       0            0         0        0        0
# 3   50    0      0      0       0            0         0        0        0
# 4   59    0      0      1       0            0         0        0        0

# %%
# Read the datafile "covid_test.csv"
df_test = pd.read_csv("covid_test.csv")

# Take a quick look at the dataframe
df_test.head()
# Out:
#    age  sex  cough  fever  chills  sore_throat  headache  fatigue  Urgency
# 0   37    0      1      0       0            0         0        0        0
# 1   21    1      0      0       0            0         0        0        1
# 2   20    1      1      1       0            0         0        0        0
# 3   30    1      0      0       0            0         0        0        1
# 4   60    0      0      1       0            0         0        0        0

# %%
# Get the train predictors
X_train = df_train.drop("Urgency", axis=1)

# Get the train response variable
y_train = df_train["Urgency"]

# %%
# Get the test predictors
X_test = df_test.drop("Urgency", axis=1)

# Get the test response variable
y_test = df_test["Urgency"]

# %%
### edTest(test_model) ###

# Define your classification model
model = KNeighborsClassifier(n_neighbors=5)

# Fit the model on the train data
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
### edTest(test_accuracy) ###

# Predict and compute the accuracy on the test data
y_pred = model.predict(X_test)

model_accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy is {model_accuracy}")
# Out:
# Model Accuracy is 0.632
